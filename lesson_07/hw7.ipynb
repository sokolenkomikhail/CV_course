# %% [markdown]
# # Обработка видео
# Классификация действий по видео

# %% [markdown]
# ## Переключение версии TensorFlow

# %%
# %tensorflow_version 2.x

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# %%
# !pip install scikit-video==1.1.11

# %%
import skvideo.io

# %% [markdown]
# ## Загрузка и распаковка датасета KTH

# %%
# !wget http://www.nada.kth.se/cvap/actions/walking.zip
# !wget http://www.nada.kth.se/cvap/actions/jogging.zip
# !wget http://www.nada.kth.se/cvap/actions/running.zip
# !wget http://www.nada.kth.se/cvap/actions/boxing.zip
# !wget http://www.nada.kth.se/cvap/actions/handwaving.zip
# !wget http://www.nada.kth.se/cvap/actions/handclapping.zip
# Out:
# --2021-10-04 20:59:35--  http://www.nada.kth.se/cvap/actions/walking.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/walking.zip [following]
# --2021-10-04 20:59:35--  https://www.csc.kth.se/cvap/actions/walking.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 242442411 (231M) [application/zip]
# Saving to: ‘walking.zip’
#
# walking.zip         100%[===================>] 231.21M  4.23MB/s    in 56s
#
# 2021-10-04 21:00:31 (4.09 MB/s) - ‘walking.zip’ saved [242442411/242442411]
#
# --2021-10-04 21:00:32--  http://www.nada.kth.se/cvap/actions/jogging.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/jogging.zip [following]
# --2021-10-04 21:00:32--  https://www.csc.kth.se/cvap/actions/jogging.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 168961290 (161M) [application/zip]
# Saving to: ‘jogging.zip’
#
# jogging.zip         100%[===================>] 161.13M  4.08MB/s    in 40s
#
# 2021-10-04 21:01:12 (4.05 MB/s) - ‘jogging.zip’ saved [168961290/168961290]
#
# --2021-10-04 21:01:12--  http://www.nada.kth.se/cvap/actions/running.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/running.zip [following]
# --2021-10-04 21:01:12--  https://www.csc.kth.se/cvap/actions/running.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149756643 (143M) [application/zip]
# Saving to: ‘running.zip’
#
# running.zip         100%[===================>] 142.82M  4.06MB/s    in 36s
#
# 2021-10-04 21:01:48 (4.00 MB/s) - ‘running.zip’ saved [149756643/149756643]
#
# --2021-10-04 21:01:48--  http://www.nada.kth.se/cvap/actions/boxing.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/boxing.zip [following]
# --2021-10-04 21:01:48--  https://www.csc.kth.se/cvap/actions/boxing.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194498294 (185M) [application/zip]
# Saving to: ‘boxing.zip’
#
# boxing.zip          100%[===================>] 185.49M  4.00MB/s    in 46s
#
# 2021-10-04 21:02:35 (4.00 MB/s) - ‘boxing.zip’ saved [194498294/194498294]
#
# --2021-10-04 21:02:35--  http://www.nada.kth.se/cvap/actions/handwaving.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/handwaving.zip [following]
# --2021-10-04 21:02:35--  https://www.csc.kth.se/cvap/actions/handwaving.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 218981954 (209M) [application/zip]
# Saving to: ‘handwaving.zip’
#
# handwaving.zip      100%[===================>] 208.84M  4.15MB/s    in 51s
#
# 2021-10-04 21:03:26 (4.06 MB/s) - ‘handwaving.zip’ saved [218981954/218981954]
#
# --2021-10-04 21:03:27--  http://www.nada.kth.se/cvap/actions/handclapping.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/handclapping.zip [following]
# --2021-10-04 21:03:27--  https://www.csc.kth.se/cvap/actions/handclapping.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 176901831 (169M) [application/zip]
# Saving to: ‘handclapping.zip’
#
# handclapping.zip    100%[===================>] 168.71M  3.99MB/s    in 42s
#
# 2021-10-04 21:04:09 (4.02 MB/s) - ‘handclapping.zip’ saved [176901831/176901831]

# %%
# !mkdir data

# %%
# !unzip -q walking.zip -d ./data/walking
# !unzip -q jogging.zip -d ./data/jogging
# !unzip -q running.zip -d ./data/running
# !unzip -q boxing.zip -d ./data/boxing
# !unzip -q handwaving.zip -d ./data/handwaving
# !unzip -q handclapping.zip -d ./data/handclapping

# %% [markdown]
# ## Подготовка датасета для классификации

# %%
DATA_PATH = './data'

classes = os.listdir(DATA_PATH)

for cls in classes:
    cls_path = os.path.join(DATA_PATH, cls)
    print(f'class {cls}: {len(os.listdir(cls_path))} samples')
# Out:
# class handwaving: 100 samples
# class handclapping: 99 samples
# class walking: 100 samples
# class jogging: 100 samples
# class boxing: 100 samples
# class running: 100 samples

# %%
test_size = 0.2
train_size = 1. - test_size
train_data = []
test_data = []

for i, cls in enumerate(classes):
    cls_path = os.path.join(DATA_PATH, cls)
    tmp = []
    for sample in os.listdir(cls_path):
        sample_path = os.path.join(cls_path, sample)
        tmp.append((sample_path, i))
    train_data += tmp[:int(len(tmp) * train_size)]
    test_data += tmp[int(len(tmp) * train_size):]

# %% [markdown]
# ## Визуализация кадра из видео

# %%
videodata = skvideo.io.vread(train_data[5][0])
videodata = videodata.astype(np.float32) / 255.
print('videodata shape:', videodata.shape)
plt.imshow(videodata[50, ...])
plt.show()
# Out:
# videodata shape: (456, 120, 160, 3)

# %%
import math
from tensorflow.keras.utils import Sequence


class KTHDataset(Sequence):
    
    def __init__(self, data, max_frames, shuffle=False, batch_size=1):
        self.data = data
        self.data_indices = list(range(len(data)))
        self.max_frames = max_frames
        self.shuffle = shuffle
        self.batch_size = batch_size
        self.on_epoch_end()
        
    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.data_indices)
        
    def _get_videodata(self, path):
        videodata = skvideo.io.vread(path)
        videodata = videodata.astype(np.float32) / 255.
        n_repeats = (self.max_frames + 1) // videodata.shape[0]
        last_frame = (self.max_frames + 1) - (videodata.shape[0] * n_repeats)
        # приведение массивов к форме (max_frames, height, width, n_channels)
        # видео с меньшим кол-вом кадров - повторяется до необходимого размера
        # видео с большим - обрезается
        videodata = np.append(
            np.repeat(videodata, n_repeats, axis=0), 
            videodata[:last_frame], 
            axis=0
        )
        # "движение"
        videodata = np.mean(
            videodata[1:, ...] - videodata[:-1, ...], 
            axis=3, 
            keepdims=True
        )
        return videodata
    
    def __getitem__(self, idx):
        batch_indices = self.data_indices[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_X = []
        batch_y = []
        for i in batch_indices:
            path, label = self.data[i]
            videodata = self._get_videodata(path)
            batch_X.append(videodata)
            batch_y.append(label)
        return np.array(batch_X), np.array(batch_y)
    
    def __len__(self):
        return math.ceil(len(self.data) / self.batch_size)

# %%
train = KTHDataset(train_data, max_frames=400, shuffle=True, batch_size=1)
test = KTHDataset(test_data, max_frames=400, shuffle=False, batch_size=1)

# %%
idx = np.random.randint(len(train))

batch_X, batch_y = train[idx]

plt.imshow(batch_X[0][-200, ..., 0], cmap='gray')
print(classes[batch_y[0]])
plt.show()
# Out:
# boxing

# %% [markdown]
# ## Создание модели CNN

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv3D(32, (5, 5, 5), (1, 2, 2), padding='same', activation='relu'),
    tf.keras.layers.MaxPool3D((1, 2, 2), padding='same'),
    tf.keras.layers.Conv3D(64, (5, 5, 5), (1, 2, 2), padding='same', activation='relu'),
    tf.keras.layers.MaxPool3D((1, 2, 2), padding='same'),
    tf.keras.layers.Conv3D(64, (3, 3, 3), (1, 2, 2), padding='same', activation='relu'),
    tf.keras.layers.MaxPool3D((1, 2, 2), padding='same'),
    tf.keras.layers.Conv3D(64, (3, 3, 3), (1, 1, 1), padding='same', activation=None),
    tf.keras.layers.GlobalAveragePooling3D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(6, activation=None),
])

# %% [markdown]
# ## Подготовка к обучению

# %%
NUM_EPOCHS = 10
LEARNING_RATE = 1e-3

model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
    optimizer=tf.keras.optimizers.Adam(LEARNING_RATE))

# %%
# !mkdir models

# %%
checkpoint_filepath = './models/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

# %%
model.fit(train, validation_data=test, epochs=10, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/10
# 479/479 [==============================] - 452s 938ms/step - loss: 1.5131 - val_loss: 1.0448
# Epoch 2/10
# 479/479 [==============================] - 449s 938ms/step - loss: 0.8221 - val_loss: 0.6355
# Epoch 3/10
# 479/479 [==============================] - 449s 938ms/step - loss: 0.6054 - val_loss: 0.4517
# Epoch 4/10
# 479/479 [==============================] - 448s 936ms/step - loss: 0.4228 - val_loss: 0.2553
# Epoch 5/10
# 479/479 [==============================] - 452s 942ms/step - loss: 0.3380 - val_loss: 0.2556
# Epoch 6/10
# 479/479 [==============================] - 455s 950ms/step - loss: 0.2519 - val_loss: 0.6325
# Epoch 7/10
# 479/479 [==============================] - 453s 945ms/step - loss: 0.2225 - val_loss: 0.2089
# Epoch 8/10
# 479/479 [==============================] - 445s 928ms/step - loss: 0.2913 - val_loss: 0.1732
# Epoch 9/10
# 479/479 [==============================] - 446s 930ms/step - loss: 0.1630 - val_loss: 0.1480
# Epoch 10/10
# 479/479 [==============================] - 444s 926ms/step - loss: 0.0956 - val_loss: 0.6813

# %%
model.load_weights(checkpoint_filepath)

# %% [markdown]
# ## Тестирование обученной модели

# %%
idx = np.random.randint(len(test))

batch_X, batch_y = test[idx]

plt.imshow(batch_X[0][200, ..., 0], cmap='gray')

out = model(batch_X)[0]
cls_pred = np.argmax(out.numpy())

print('True class:', classes[batch_y[0]])
print('Predicted class:', classes[cls_pred])
plt.show()
# Out:
# True class: jogging
# Predicted class: jogging
